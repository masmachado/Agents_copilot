# %% [markdown]
# # Tabela: tb_mov_vendas
#
# Tags da tabela (incompletas de propósito):
# - UpdateFrequency: daily
# - LoadType: incremental
#
# Tags de coluna (incompletas de propósito):
# - id_cliente: Confidentiality=internal, PK=true, Privacy=pii

# %% [markdown]
# Aplicação de tags (mock)
